# %%
import pandas as pd

# %%
ca_1_fold0=pd.read_csv('all_preds_CA_10.csv')
ca_1_fold1=pd.read_csv('all_preds_CA_11.csv')
ca_1_fold2=pd.read_csv('all_preds_CA_12.csv')

# %%
ca_1_fold0.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.819718  0.789495  0.715193  0.694988
# 1  HOBBIES_1_002_CA_1_validation  0.208543  0.195609  0.182678  0.198086
# 2  HOBBIES_1_003_CA_1_validation  0.433035  0.408138  0.418708  0.452256
# 3  HOBBIES_1_004_CA_1_validation  1.823068  1.350429  1.459897  1.614831
# 4  HOBBIES_1_005_CA_1_validation  0.929174  0.842389  0.819604  0.862624
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.893756  1.099176  1.322506  0.986605  1.017411  ...  0.927104  1.235203
# 1  0.202571  0.243464  0.255973  0.205186  0.196315  ...  0.172401  0.220847
# 2  0.563781  0.673336  0.621797  0.411974  0.443716  ...  0.508033  0.611367
# 3  1.945576  3.185691  3.079158  1.709985  1.552077  ...  2.057046  2.584429
# 4  1.055868  1.215278  1.501977  1.049867  1.090943  ...  1.122549  1.482713
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.162732  0.870165  0.875318  0.853910  0.904976  0.992453  1.155789
# 1  0.235425  0.194310  0.182487  0.193609  0.199889  0.189463  0.246207
# 2  0.642690  0.439520  0.388405  0.399873  0.413721  0.529632  0.654814
# 3  3.080540  1.749694  1.526981  1.389099  1.467144  1.937259  2.954175
# 4  1.532526  0.953234  0.906297  0.892783  0.867830  1.108545  1.468702
#
#         F28
# 0  1.105978
# 1  0.257613
# 2  0.649236
# 3  3.420800
# 4  1.467546
#
# [5 rows x 29 columns]

# %%
ca_1_fold0.shape
# Out:
# (3049, 29)

# %%
ca_1=pd.DataFrame()
ca_1['id']=ca_1_fold0['id']
for item in ca_1_fold0:
    if item!='id':
        ca_1[item]=(ca_1_fold0[item]*(1/3))+(ca_1_fold1[item]*(1/3))+(ca_1_fold2[item]*(1/3))

# %%
ca_1.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.800591  0.721052  0.699087  0.716033
# 1  HOBBIES_1_002_CA_1_validation  0.235175  0.202927  0.194480  0.206629
# 2  HOBBIES_1_003_CA_1_validation  0.424499  0.393233  0.389383  0.421700
# 3  HOBBIES_1_004_CA_1_validation  1.722686  1.392649  1.457743  1.523619
# 4  HOBBIES_1_005_CA_1_validation  0.978231  0.860466  0.877678  0.885267
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.900652  1.006862  1.098142  0.888580  0.893960  ...  0.858901  1.084498
# 1  0.234990  0.283472  0.331728  0.228708  0.214172  ...  0.206490  0.252850
# 2  0.535415  0.635250  0.634219  0.439349  0.451471  ...  0.541053  0.663947
# 3  1.937231  2.818198  3.028485  1.798333  1.574605  ...  1.991805  2.678268
# 4  1.076716  1.351907  1.454577  1.033740  1.069710  ...  1.116447  1.568735
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.028875  0.822289  0.783098  0.744775  0.781652  0.878970  1.041098
# 1  0.256090  0.202857  0.185182  0.192939  0.198472  0.211768  0.278735
# 2  0.700224  0.497394  0.447149  0.455086  0.471961  0.570536  0.684352
# 3  3.126738  1.759391  1.514683  1.457175  1.441877  1.955518  3.007029
# 4  1.598901  0.996234  0.932226  0.942742  0.924118  1.168102  1.535467
#
#         F28
# 0  0.987187
# 1  0.291158
# 2  0.657766
# 3  3.316363
# 4  1.510697
#
# [5 rows x 29 columns]

# %%
ca_1.shape
# Out:
# (3049, 29)

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')

# %%
sub.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.841310  0.780816  0.755726  0.732071
# 1  HOBBIES_1_002_CA_1_validation  0.206519  0.191507  0.172134  0.202713
# 2  HOBBIES_1_003_CA_1_validation  0.443345  0.408751  0.429146  0.425363
# 3  HOBBIES_1_004_CA_1_validation  1.672548  1.365069  1.323705  1.507489
# 4  HOBBIES_1_005_CA_1_validation  0.970362  0.842148  0.894868  0.860903
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.906987  0.980494  1.100806  0.880358  0.840556  ...  0.839435  1.090193
# 1  0.218178  0.290731  0.302245  0.209692  0.200329  ...  0.205168  0.262049
# 2  0.552568  0.638499  0.699324  0.528112  0.471524  ...  0.544495  0.735714
# 3  2.113503  2.898886  3.210592  1.803483  1.554177  ...  1.998574  2.659329
# 4  1.058545  1.361341  1.455360  1.033733  1.039133  ...  1.119777  1.565799
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.028382  0.838720  0.801584  0.742520  0.793294  0.857438  1.054456
# 1  0.266381  0.182875  0.165946  0.176802  0.187321  0.187024  0.245337
# 2  0.738077  0.465108  0.409136  0.410397  0.441521  0.555661  0.675365
# 3  3.237022  1.700170  1.401813  1.410481  1.327478  1.995211  2.862200
# 4  1.686430  0.982957  0.893096  0.921336  0.922060  1.179444  1.540157
#
#         F28
# 0  0.994806
# 1  0.268075
# 2  0.644728
# 3  3.520612
# 4  1.550996
#
# [5 rows x 29 columns]

# %%
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_1['id']))]=list(ca_1[item])
# Out:
# /Users/shuozhang/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sub.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.800591  0.721052  0.699087  0.716033
# 1  HOBBIES_1_002_CA_1_validation  0.235175  0.202927  0.194480  0.206629
# 2  HOBBIES_1_003_CA_1_validation  0.424499  0.393233  0.389383  0.421700
# 3  HOBBIES_1_004_CA_1_validation  1.722686  1.392649  1.457743  1.523619
# 4  HOBBIES_1_005_CA_1_validation  0.978231  0.860466  0.877678  0.885267
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.900652  1.006862  1.098142  0.888580  0.893960  ...  0.858901  1.084498
# 1  0.234990  0.283472  0.331728  0.228708  0.214172  ...  0.206490  0.252850
# 2  0.535415  0.635250  0.634219  0.439349  0.451471  ...  0.541053  0.663947
# 3  1.937231  2.818198  3.028485  1.798333  1.574605  ...  1.991805  2.678268
# 4  1.076716  1.351907  1.454577  1.033740  1.069710  ...  1.116447  1.568735
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.028875  0.822289  0.783098  0.744775  0.781652  0.878970  1.041098
# 1  0.256090  0.202857  0.185182  0.192939  0.198472  0.211768  0.278735
# 2  0.700224  0.497394  0.447149  0.455086  0.471961  0.570536  0.684352
# 3  3.126738  1.759391  1.514683  1.457175  1.441877  1.955518  3.007029
# 4  1.598901  0.996234  0.932226  0.942742  0.924118  1.168102  1.535467
#
#         F28
# 0  0.987187
# 1  0.291158
# 2  0.657766
# 3  3.316363
# 4  1.510697
#
# [5 rows x 29 columns]

# %%
sub.to_csv('lgb_3fold_ca1_morefe.csv',index=False)  #0.46838:0.46861

# %%
ca_2_fold0=pd.read_csv('all_preds_CA_20.csv')
ca_2_fold1=pd.read_csv('all_preds_CA_21.csv')
ca_2_fold2=pd.read_csv('all_preds_CA_22.csv')
ca_2=pd.DataFrame()
ca_2['id']=ca_2_fold0['id']
for item in ca_2_fold0:
    if item!='id':
        ca_2[item]=(ca_2_fold0[item]*(1/3))+(ca_2_fold1[item]*(1/3))+(ca_2_fold2[item]*(1/3))

# %%
ca_2.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_2_validation  0.554120  0.572517  0.575680  0.597394
# 1  HOBBIES_1_002_CA_2_validation  0.090036  0.089498  0.089953  0.083029
# 2  HOBBIES_1_003_CA_2_validation  0.331831  0.314198  0.322670  0.321218
# 3  HOBBIES_1_004_CA_2_validation  2.682044  2.958185  2.936726  2.606411
# 4  HOBBIES_1_005_CA_2_validation  1.276880  1.292732  1.227343  1.152410
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.645332  0.819207  0.811281  0.711818  0.660376  ...  0.750522  0.880877
# 1  0.117509  0.159510  0.178960  0.098224  0.092288  ...  0.128127  0.206519
# 2  0.407923  0.512960  0.530255  0.337005  0.343311  ...  0.423864  0.596632
# 3  2.938964  3.337540  3.514607  2.690491  2.958112  ...  3.303681  4.146206
# 4  1.302721  1.715361  1.686258  1.285153  1.249886  ...  1.381984  1.807331
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  0.887305  0.675053  0.616533  0.652283  0.608828  0.726635  0.934487
# 1  0.199786  0.111608  0.109406  0.112872  0.116109  0.150959  0.226964
# 2  0.569255  0.338462  0.352440  0.331862  0.326569  0.399417  0.595550
# 3  3.972776  3.064031  2.651794  2.682491  2.800985  3.095258  4.089912
# 4  1.806522  1.262656  1.234310  1.158831  1.207116  1.365785  1.762203
#
#         F28
# 0  0.960041
# 1  0.218913
# 2  0.589559
# 3  3.740945
# 4  1.739408
#
# [5 rows x 29 columns]

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_2['id']))]=list(ca_2[item])
sub.to_csv('lgb_3fold_ca2_morefe.csv',index=False)#0.46838:0.46767

# %%
sub.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.841310  0.780816  0.755726  0.732071
# 1  HOBBIES_1_002_CA_1_validation  0.206519  0.191507  0.172134  0.202713
# 2  HOBBIES_1_003_CA_1_validation  0.443345  0.408751  0.429146  0.425363
# 3  HOBBIES_1_004_CA_1_validation  1.672548  1.365069  1.323705  1.507489
# 4  HOBBIES_1_005_CA_1_validation  0.970362  0.842148  0.894868  0.860903
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.906987  0.980494  1.100806  0.880358  0.840556  ...  0.839435  1.090193
# 1  0.218178  0.290731  0.302245  0.209692  0.200329  ...  0.205168  0.262049
# 2  0.552568  0.638499  0.699324  0.528112  0.471524  ...  0.544495  0.735714
# 3  2.113503  2.898886  3.210592  1.803483  1.554177  ...  1.998574  2.659329
# 4  1.058545  1.361341  1.455360  1.033733  1.039133  ...  1.119777  1.565799
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.028382  0.838720  0.801584  0.742520  0.793294  0.857438  1.054456
# 1  0.266381  0.182875  0.165946  0.176802  0.187321  0.187024  0.245337
# 2  0.738077  0.465108  0.409136  0.410397  0.441521  0.555661  0.675365
# 3  3.237022  1.700170  1.401813  1.410481  1.327478  1.995211  2.862200
# 4  1.686430  0.982957  0.893096  0.921336  0.922060  1.179444  1.540157
#
#         F28
# 0  0.994806
# 1  0.268075
# 2  0.644728
# 3  3.520612
# 4  1.550996
#
# [5 rows x 29 columns]

# %%
sub[sub['id']=='HOBBIES_1_001_CA_2_validation']
# Out:
#                                  id       F1        F2       F3        F4  \
# 3049  HOBBIES_1_001_CA_2_validation  0.55412  0.572517  0.57568  0.597394
#
#             F5        F6        F7        F8        F9  ...       F19  \
# 3049  0.645332  0.819207  0.811281  0.711818  0.660376  ...  0.750522
#
#            F20       F21       F22       F23       F24       F25       F26  \
# 3049  0.880877  0.887305  0.675053  0.616533  0.652283  0.608828  0.726635
#
#            F27       F28
# 3049  0.934487  0.960041
#
# [1 rows x 29 columns]

# %%
sub.shape
# Out:
# (60980, 29)

# %%
ca_3_fold0=pd.read_csv('all_preds_CA_30.csv')
ca_3_fold1=pd.read_csv('all_preds_CA_31.csv')
ca_3_fold2=pd.read_csv('all_preds_CA_32.csv')
ca_3=pd.DataFrame()
ca_3['id']=ca_3_fold0['id']
for item in ca_3_fold0:
    if item!='id':
        ca_3[item]=(ca_3_fold0[item]*(1/3))+(ca_3_fold1[item]*(1/3))+(ca_3_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_3['id']))]=list(ca_3[item])
sub.to_csv('lgb_3fold_ca3_morefe.csv',index=False) #0.46838:0.46831

# %%
ca_4_fold0=pd.read_csv('all_preds_CA_40.csv')
ca_4_fold1=pd.read_csv('all_preds_CA_41.csv')
ca_4_fold2=pd.read_csv('all_preds_CA_42.csv')
ca_4=pd.DataFrame()
ca_4['id']=ca_4_fold0['id']
for item in ca_4_fold0:
    if item!='id':
        ca_4[item]=(ca_4_fold0[item]*(1/3))+(ca_4_fold1[item]*(1/3))+(ca_4_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_4['id']))]=list(ca_4[item])
sub.to_csv('lgb_3fold_ca4_morefe.csv',index=False)#0.46838:0.46853

# %%
tx_1_fold0=pd.read_csv('all_preds_TX_10.csv')
tx_1_fold1=pd.read_csv('all_preds_TX_11.csv')
tx_1_fold2=pd.read_csv('all_preds_TX_12.csv')
tx_1=pd.DataFrame()
tx_1['id']=tx_1_fold0['id']
for item in tx_1_fold0:
    if item!='id':
        tx_1[item]=(tx_1_fold0[item]*(1/3))+(tx_1_fold1[item]*(1/3))+(tx_1_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_1['id']))]=list(tx_1[item])
sub.to_csv('lgb_3fold_tx1_morefe.csv',index=False) #0.46838:0.46819

# %%
tx_2_fold0=pd.read_csv('all_preds_TX_20.csv')
tx_2_fold1=pd.read_csv('all_preds_TX_21.csv')
tx_2_fold2=pd.read_csv('all_preds_TX_22.csv')
tx_2=pd.DataFrame()
tx_2['id']=tx_2_fold0['id']
for item in tx_2_fold0:
    if item!='id':
        tx_2[item]=(tx_2_fold0[item]*(1/3))+(tx_2_fold1[item]*(1/3))+(tx_2_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_2['id']))]=list(tx_2[item])
sub.to_csv('lgb_3fold_tx2_morefe.csv',index=False) #0.46838:0.46838

# %%
tx_3_fold0=pd.read_csv('all_preds_TX_30.csv')
tx_3_fold1=pd.read_csv('all_preds_TX_31.csv')
tx_3_fold2=pd.read_csv('all_preds_TX_32.csv')
tx_3=pd.DataFrame()
tx_3['id']=tx_3_fold0['id']
for item in tx_3_fold0:
    if item!='id':
        tx_3[item]=(tx_3_fold0[item]*(1/3))+(tx_3_fold1[item]*(1/3))+(tx_3_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_3['id']))]=list(tx_3[item])
sub.to_csv('lgb_3fold_tx3_morefe.csv',index=False) #0.46838:0.46769

# %%
wi_1_fold0=pd.read_csv('all_preds_WI_10.csv')
wi_1_fold1=pd.read_csv('all_preds_WI_11.csv')
wi_1_fold2=pd.read_csv('all_preds_WI_12.csv')
wi_1=pd.DataFrame()
wi_1['id']=wi_1_fold0['id']
for item in wi_1_fold0:
    if item!='id':
        wi_1[item]=(wi_1_fold0[item]*(1/3))+(wi_1_fold1[item]*(1/3))+(wi_1_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_1['id']))]=list(wi_1[item])
sub.to_csv('lgb_3fold_wi1_morefe.csv',index=False) #0.46838:0.46710

# %%
wi_2_fold0=pd.read_csv('all_preds_WI_20.csv')
wi_2_fold1=pd.read_csv('all_preds_WI_21.csv')
wi_2_fold2=pd.read_csv('all_preds_WI_22.csv')
wi_2=pd.DataFrame()
wi_2['id']=wi_2_fold0['id']
for item in wi_2_fold0:
    if item!='id':
        wi_2[item]=(wi_2_fold0[item]*(1/3))+(wi_2_fold1[item]*(1/3))+(wi_2_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_2['id']))]=list(wi_2[item])
sub.to_csv('lgb_3fold_wi2_morefe.csv',index=False)#0.46838:0.47062

# %%
wi_3_fold0=pd.read_csv('all_preds_WI_30.csv')
wi_3_fold1=pd.read_csv('all_preds_WI_31.csv')
wi_3_fold2=pd.read_csv('all_preds_WI_32.csv')
wi_3=pd.DataFrame()
wi_3['id']=wi_3_fold0['id']
for item in wi_3_fold0:
    if item!='id':
        wi_3[item]=(wi_3_fold0[item]*(1/3))+(wi_3_fold1[item]*(1/3))+(wi_3_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_3['id']))]=list(wi_3[item])
sub.to_csv('lgb_3fold_wi3_morefe.csv',index=False) #0.46838:0.46997

# %%
ca_1.shape[0]+ca_2.shape[0]+ca_3.shape[0]+ca_4.shape[0]+tx_1.shape[0]+tx_2.shape[0]+tx_3.shape[0]+wi_1.shape[0]+\
wi_2.shape[0]+wi_3.shape[0]
# Out:
# 30490

# %%
all_preds=pd.concat([ca_1,ca_2,ca_3,ca_4,tx_1,tx_2,tx_3,wi_1,wi_2,wi_3], axis=0)

# %%
all_preds.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.800591  0.721052  0.699087  0.716033
# 1  HOBBIES_1_002_CA_1_validation  0.235175  0.202927  0.194480  0.206629
# 2  HOBBIES_1_003_CA_1_validation  0.424499  0.393233  0.389383  0.421700
# 3  HOBBIES_1_004_CA_1_validation  1.722686  1.392649  1.457743  1.523619
# 4  HOBBIES_1_005_CA_1_validation  0.978231  0.860466  0.877678  0.885267
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.900652  1.006862  1.098142  0.888580  0.893960  ...  0.858901  1.084498
# 1  0.234990  0.283472  0.331728  0.228708  0.214172  ...  0.206490  0.252850
# 2  0.535415  0.635250  0.634219  0.439349  0.451471  ...  0.541053  0.663947
# 3  1.937231  2.818198  3.028485  1.798333  1.574605  ...  1.991805  2.678268
# 4  1.076716  1.351907  1.454577  1.033740  1.069710  ...  1.116447  1.568735
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.028875  0.822289  0.783098  0.744775  0.781652  0.878970  1.041098
# 1  0.256090  0.202857  0.185182  0.192939  0.198472  0.211768  0.278735
# 2  0.700224  0.497394  0.447149  0.455086  0.471961  0.570536  0.684352
# 3  3.126738  1.759391  1.514683  1.457175  1.441877  1.955518  3.007029
# 4  1.598901  0.996234  0.932226  0.942742  0.924118  1.168102  1.535467
#
#         F28
# 0  0.987187
# 1  0.291158
# 2  0.657766
# 3  3.316363
# 4  1.510697
#
# [5 rows x 29 columns]

# %%
all_preds.shape
# Out:
# (30490, 29)

# %%
submission=pd.read_csv('sample_submission.csv')

# %%
submission=submission[['id']]

# %%
sub=submission.merge(all_preds, on=['id'], how='left').fillna(0)

# %%
sub.to_csv('lgb_bystore_3fold_fe.csv', index=False)

# %%
#replacement

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_1['id']))]=list(wi_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_2['id']))]=list(ca_2[item])
sub.to_csv('lgb_3fold_wi1_ca2_morefe.csv',index=False) ##0.46710:0.46641

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_1['id']))]=list(wi_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_2['id']))]=list(ca_2[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_3['id']))]=list(tx_3[item])
sub.to_csv('lgb_3fold_wi1_ca2_tx3_morefe.csv',index=False) #0.46641:0.46578

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_1['id']))]=list(wi_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_2['id']))]=list(ca_2[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_3['id']))]=list(tx_3[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_1['id']))]=list(tx_1[item])
sub.to_csv('lgb_3fold_wi1_ca2_tx3_tx1_morefe.csv',index=False) #0.46578:0.46568

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_1['id']))]=list(wi_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_2['id']))]=list(ca_2[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_3['id']))]=list(tx_3[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_1['id']))]=list(tx_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_3['id']))]=list(ca_3[item])
sub.to_csv('lgb_3fold_wi1_ca2_tx3_tx1_ca3_morefe.csv',index=False) #0.46568:0.46566

# %%
sub=pd.read_csv('lgb_bystore_morefe.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(wi_1['id']))]=list(wi_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_2['id']))]=list(ca_2[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_3['id']))]=list(tx_3[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_1['id']))]=list(tx_1[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(ca_3['id']))]=list(ca_3[item])
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(tx_2['id']))]=list(tx_2[item])
sub.to_csv('lgb_3fold_wi1_ca2_tx3_tx1_ca3_tx2_morefe.csv',index=False)  #0.46566:0.46580
