# %%
# General imports
import numpy as np
import pandas as pd
import os, sys, gc, time, warnings, pickle, psutil, random
from sklearn.model_selection import GroupKFold
# custom imports
from multiprocessing import Pool        # Multiprocess Runs

warnings.filterwarnings('ignore')

# %%
########################### Helpers
#################################################################################
## Seeder
# :seed to make all processes deterministic     # type: int
def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)

    
## Multiprocess Runs
def df_parallelize_run(func, t_split):
    num_cores = np.min([N_CORES,len(t_split)])
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, t_split), axis=1)
    pool.close()
    pool.join()
    return df

# %%
########################### Helper to load data by store ID
#################################################################################
# Read data
def get_data_by_store(store):
    
    # Read and contact basic feature
    df = pd.concat([pd.read_pickle(BASE),
                    pd.read_pickle(PRICE).iloc[:,2:],
                    pd.read_pickle(CALENDAR).iloc[:,2:]],
                    axis=1)
    
    # Leave only relevant store
    df = df[df['store_id']==store]

    # With memory limits we have to read 
    # lags and mean encoding features
    # separately and drop items that we don't need.
    # As our Features Grids are aligned 
    # we can use index to keep only necessary rows
    # Alignment is good for us as concat uses less memory than merge.
    df2 = pd.read_pickle(MEAN_ENC)[mean_features]
    df2 = df2[df2.index.isin(df.index)]
    
    df3 = pd.read_pickle(LAGS).iloc[:,3:]
    df3 = df3[df3.index.isin(df.index)]
    
    df = pd.concat([df, df2], axis=1)
    del df2 # to not reach memory limit 
    
    df = pd.concat([df, df3], axis=1)
    del df3 # to not reach memory limit 
    
    # Create features list
    features = [col for col in list(df) if col not in remove_features]
    df = df[['id','d',TARGET]+features]
    
    # Skipping first n rows
    df = df[df['d']>=START_TRAIN].reset_index(drop=True)
    
    return df, features

# Recombine Test set after training
def get_base_test():
    base_test = pd.DataFrame()

    for store_id in STORES_IDS:
        temp_df = pd.read_pickle('test_'+store_id+'.pkl')
        temp_df['store_id'] = store_id
        base_test = pd.concat([base_test, temp_df]).reset_index(drop=True)
    
    return base_test


########################### Helper to make dynamic rolling lags
#################################################################################
def make_lag(LAG_DAY):
    lag_df = base_test[['id','d',TARGET]]
    col_name = 'sales_lag_'+str(LAG_DAY)
    lag_df[col_name] = lag_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(LAG_DAY)).astype(np.float16)
    return lag_df[[col_name]]


def make_lag_roll(LAG_DAY):
    shift_day = LAG_DAY[0]
    roll_wind = LAG_DAY[1]
    lag_df = base_test[['id','d',TARGET]]
    col_name = 'rolling_mean_tmp_'+str(shift_day)+'_'+str(roll_wind)
    lag_df[col_name] = lag_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(shift_day).rolling(roll_wind).mean())
    return lag_df[[col_name]]

# %%
########################### Model params
#################################################################################
import lightgbm as lgb
lgb_params = {
                    'boosting_type': 'gbdt',
                    'objective': 'tweedie',
                    'tweedie_variance_power': 1.1,
                    'metric': 'rmse',
                    'subsample': 0.5,
                    'subsample_freq': 1,
                    'learning_rate': 0.03,
                    'num_leaves': 2**11-1,
                    'min_data_in_leaf': 2**12-1,
                    'feature_fraction': 0.5,
                    'max_bin': 100,
                    'n_estimators': 1400,
                    'boost_from_average': False,
                    'verbose': 1,
                } 


# Let's look closer on params

## 'boosting_type': 'gbdt'
# we have 'goss' option for faster training
# but it normally leads to underfit.
# Also there is good 'dart' mode
# but it takes forever to train
# and model performance depends 
# a lot on random factor 
# https://www.kaggle.com/c/home-credit-default-risk/discussion/60921

## 'objective': 'tweedie'
# Tweedie Gradient Boosting for Extremely
# Unbalanced Zero-inflated Data
# https://arxiv.org/pdf/1811.10192.pdf
# and many more articles about tweediie
#
# Strange (for me) but Tweedie is close in results
# to my own ugly loss.
# My advice here - make OWN LOSS function
# https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/140564
# https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/143070
# I think many of you already using it (after poisson kernel appeared) 
# (kagglers are very good with "params" testing and tuning).
# Try to figure out why Tweedie works.
# probably it will show you new features options
# or data transformation (Target transformation?).

## 'tweedie_variance_power': 1.1
# default = 1.5
# set this closer to 2 to shift towards a Gamma distribution
# set this closer to 1 to shift towards a Poisson distribution
# my CV shows 1.1 is optimal 
# but you can make your own choice

## 'metric': 'rmse'
# Doesn't mean anything to us
# as competition metric is different
# and we don't use early stoppings here.
# So rmse serves just for general 
# model performance overview.
# Also we use "fake" validation set
# (as it makes part of the training set)
# so even general rmse score doesn't mean anything))
# https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/133834

## 'subsample': 0.5
# Serves to fight with overfit
# this will randomly select part of data without resampling
# Chosen by CV (my CV can be wrong!)
# Next kernel will be about CV

##'subsample_freq': 1
# frequency for bagging
# default value - seems ok

## 'learning_rate': 0.03
# Chosen by CV
# Smaller - longer training
# but there is an option to stop 
# in "local minimum"
# Bigger - faster training
# but there is a chance to
# not find "global minimum" minimum

## 'num_leaves': 2**11-1
## 'min_data_in_leaf': 2**12-1
# Force model to use more features
# We need it to reduce "recursive"
# error impact.
# Also it leads to overfit
# that's why we use small 
# 'max_bin': 100

## l1, l2 regularizations
# https://towardsdatascience.com/l1-and-l2-regularization-methods-ce25e7fc831c
# Good tiny explanation
# l2 can work with bigger num_leaves
# but my CV doesn't show boost
                    
## 'n_estimators': 1400
# CV shows that there should be
# different values for each state/store.
# Current value was chosen 
# for general purpose.
# As we don't use any early stopings
# careful to not overfit Public LB.

##'feature_fraction': 0.5
# LightGBM will randomly select 
# part of features on each iteration (tree).
# We have maaaany features
# and many of them are "duplicates"
# and many just "noise"
# good values here - 0.5-0.7 (by CV)

## 'boost_from_average': False
# There is some "problem"
# to code boost_from_average for 
# custom loss
# 'True' makes training faster
# BUT carefull use it
# https://github.com/microsoft/LightGBM/issues/1514
# not our case but good to know cons

# %%
########################### Vars
#################################################################################
SEED = 42                        # We want all things
seed_everything(SEED)            # to be as deterministic 
lgb_params['seed'] = SEED        # as possible
N_CORES = psutil.cpu_count()     # Available CPU cores


#LIMITS and const
TARGET      = 'sales'            # Our target
START_TRAIN = 0                  # We can skip some rows (Nans/faster training)
END_TRAIN   = 1913               # End day of our train set
P_HORIZON   = 28                 # Prediction horizon
USE_AUX     = True               # Use or not pretrained models

#FEATURES to remove
## These features lead to overfit
## or values not present in test set
remove_features = ['id','state_id','store_id',
                   'date','wm_yr_wk','d',TARGET]
mean_features   = ['enc_cat_id_mean','enc_cat_id_std',
                   'enc_dept_id_mean','enc_dept_id_std',
                   'enc_item_id_mean','enc_item_id_std'] 

#PATHS for Features
BASE     = 'grid_part_1.pkl'
PRICE    = 'grid_part_2.pkl'
CALENDAR = 'grid_part_3.pkl'
LAGS     = 'lags_df_28.pkl'
MEAN_ENC = 'mean_encoding_df.pkl'

#STORES ids
# STORES_IDS = pd.read_csv(ORIGINAL+'sales_train_validation.csv')['store_id']
# STORES_IDS = list(STORES_IDS.unique())
STORES_IDS = ['CA_2'] # It takes around 5hrs to train for each store. Please run multiple kernels for each store.

#FOLDS
CV_FOLDS = [0,1,2]

#SPLITS for lags creation
SHIFT_DAY  = 28
N_LAGS     = 15
LAGS_SPLIT = [col for col in range(SHIFT_DAY,SHIFT_DAY+N_LAGS)]
ROLS_SPLIT = []
for i in [1,7,14]:
    for j in [7,14,28,56]:
        ROLS_SPLIT.append([i,j])

# %%
########################### Train Models
#################################################################################
for store_id in STORES_IDS:
    print('Train', store_id)
    
    # Get grid for current store
    grid_df, features_columns = get_data_by_store(store_id)
    
    # Masks for 
    # Train (All data less than 1913)
    # "Validation" (Last 28 days - not real validatio set)
    # Test (All data greater than 1913 day, 
    #       with some gap for recursive features)
    train_mask = grid_df['d']<=END_TRAIN
    preds_mask = grid_df['d']>(END_TRAIN-100)
    
    ## Initiating our GroupKFold
    folds = GroupKFold(n_splits=3)

    # get subgroups for each week, year pair
    grid_df['groups'] = grid_df['tm_w'].astype(str) + '_' + grid_df['tm_y'].astype(str)
    split_groups = grid_df[train_mask]['groups']

    # Main Data
    X,y = grid_df[train_mask][features_columns], grid_df[train_mask][TARGET]
        
    # Saving part of the dataset for later predictions
    # Removing features that we need to calculate recursively 
    grid_df = grid_df[preds_mask].reset_index(drop=True)
    keep_cols = [col for col in list(grid_df) if '_tmp_' not in col]
    grid_df = grid_df[keep_cols]
    grid_df.to_pickle('test_'+store_id+'.pkl')
    del grid_df
    
    # Launch seeder again to make lgb training 100% deterministic
    # with each "code line" np.random "evolves" 
    # so we need (may want) to "reset" it
    
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y, groups=split_groups)):
        print('Fold:',fold_)
        print(len(trn_idx),len(val_idx))
        tr_x, tr_y = X.iloc[trn_idx,:], y[trn_idx]
        v_X, v_y   = X.iloc[val_idx,:], y[val_idx] 
        train_data = lgb.Dataset(tr_x, label=tr_y)
        valid_data = lgb.Dataset(v_X, label=v_y)  

        seed_everything(SEED)
        estimator = lgb.train(
                lgb_params,
                train_data,
                valid_sets = [train_data, valid_data],
                verbose_eval = 100,
            )
        # Save model - it's not real '.bin' but a pickle file
        # estimator = lgb.Booster(model_file='model.txt')
        # can only predict with the best iteration (or the saving iteration)
        # pickle.dump gives us more flexibility
        # like estimator.predict(TEST, num_iteration=100)
        # num_iteration - number of iteration want to predict with, 
        # NULL or <= 0 means use best iteration
        model_name = 'lgb_model_'+STORES_IDS[0]+'_'+str(fold_)+'.bin'
        pickle.dump(estimator, open(model_name, 'wb'))

        # Remove temporary files and objects 
        # to free some hdd space and ram memory
        del train_data, valid_data, estimator
        gc.collect()

    # "Keep" models features for predictions
    MODEL_FEATURES = features_columns
# Out:
# Train CA_2
# Fold: 0
# 2851542 1424234
# [100]	training's rmse: 2.0626	valid_1's rmse: 2.05822
# [200]	training's rmse: 2.01906	valid_1's rmse: 2.02683
# [300]	training's rmse: 2.00229	valid_1's rmse: 2.01915
# [400]	training's rmse: 1.99017	valid_1's rmse: 2.01433
# [500]	training's rmse: 1.97992	valid_1's rmse: 2.01138
# [600]	training's rmse: 1.97146	valid_1's rmse: 2.00979
# [700]	training's rmse: 1.96325	valid_1's rmse: 2.00859
# [800]	training's rmse: 1.95508	valid_1's rmse: 2.00784
# [900]	training's rmse: 1.94804	valid_1's rmse: 2.00742
# [1000]	training's rmse: 1.94105	valid_1's rmse: 2.00703
# [1100]	training's rmse: 1.93462	valid_1's rmse: 2.00701
# [1200]	training's rmse: 1.92877	valid_1's rmse: 2.00672
# [1300]	training's rmse: 1.92282	valid_1's rmse: 2.00675
# [1400]	training's rmse: 1.91691	valid_1's rmse: 2.00659
# Fold: 1
# 2853521 1422255
# [100]	training's rmse: 2.06041	valid_1's rmse: 2.05882
# [200]	training's rmse: 2.01876	valid_1's rmse: 2.02454
# [300]	training's rmse: 2.00186	valid_1's rmse: 2.01765
# [400]	training's rmse: 1.98945	valid_1's rmse: 2.01413
# [500]	training's rmse: 1.97926	valid_1's rmse: 2.01227
# [600]	training's rmse: 1.97036	valid_1's rmse: 2.01066
# [700]	training's rmse: 1.96231	valid_1's rmse: 2.00992
# [800]	training's rmse: 1.95418	valid_1's rmse: 2.00896
# [900]	training's rmse: 1.94692	valid_1's rmse: 2.00831
# [1000]	training's rmse: 1.9403	valid_1's rmse: 2.00797
# [1100]	training's rmse: 1.93381	valid_1's rmse: 2.00784
# [1200]	training's rmse: 1.92803	valid_1's rmse: 2.00776
# [1300]	training's rmse: 1.9218	valid_1's rmse: 2.00783
# [1400]	training's rmse: 1.91628	valid_1's rmse: 2.00758
# Fold: 2
# 2846489 1429287
# [100]	training's rmse: 2.0508	valid_1's rmse: 2.09146
# [200]	training's rmse: 2.00703	valid_1's rmse: 2.05787
# [300]	training's rmse: 1.99104	valid_1's rmse: 2.04942
# [400]	training's rmse: 1.97962	valid_1's rmse: 2.04502
# [500]	training's rmse: 1.97011	valid_1's rmse: 2.04218
# [600]	training's rmse: 1.9619	valid_1's rmse: 2.04074
# [700]	training's rmse: 1.95409	valid_1's rmse: 2.03918
# [800]	training's rmse: 1.94651	valid_1's rmse: 2.03799
# [900]	training's rmse: 1.93949	valid_1's rmse: 2.03677
# [1000]	training's rmse: 1.93327	valid_1's rmse: 2.03613
# [1100]	training's rmse: 1.92711	valid_1's rmse: 2.03561
# [1200]	training's rmse: 1.92132	valid_1's rmse: 2.03479
# [1300]	training's rmse: 1.91575	valid_1's rmse: 2.0345
# [1400]	training's rmse: 1.9101	valid_1's rmse: 2.03407

# %%
for fold_ in CV_FOLDS:
    print("FOLD:", fold_)
    # Join back the Test dataset with 
    # a small part of the training data 
    # to make recursive features
    all_preds = pd.DataFrame()
    base_test = get_base_test()
    # Timer to measure predictions time 
    main_time = time.time()

    # Loop over each prediction day
    # As rolling lags are the most timeconsuming
    # we will calculate it for whole day
    for PREDICT_DAY in range(1,29):    
        print('Predict | Day:', PREDICT_DAY)
        start_time = time.time()

        # Make temporary grid to calculate rolling lags
        grid_df = base_test.copy()
        grid_df = pd.concat([grid_df, df_parallelize_run(make_lag_roll, ROLS_SPLIT)], axis=1)

        for store_id in STORES_IDS:
        
            # Read all our models and make predictions
            # for each day/store pairs
            model_path = 'lgb_model_'+store_id+'_'+str(fold_)+'.bin' 

            estimator = pickle.load(open(model_path, 'rb'))

            day_mask = base_test['d']==(END_TRAIN+PREDICT_DAY)
            store_mask = base_test['store_id']==store_id

            mask = (day_mask)&(store_mask)
            base_test[TARGET][mask] = estimator.predict(grid_df[mask][MODEL_FEATURES])

        # Make good column naming and add 
        # to all_preds DataFrame
        temp_df = base_test[day_mask][['id',TARGET]]
        temp_df.columns = ['id','F'+str(PREDICT_DAY)]
        if 'id' in list(all_preds):
            all_preds = all_preds.merge(temp_df, on=['id'], how='left')
        else:
            all_preds = temp_df.copy()
        all_preds = all_preds.reset_index(drop=True)
        print('#'*10, ' %0.2f min round |' % ((time.time() - start_time) / 60),
                      ' %0.2f min total |' % ((time.time() - main_time) / 60),
                      ' %0.2f day sales |' % (temp_df['F'+str(PREDICT_DAY)].sum()))
    all_preds.to_csv('all_preds_CA_2'+str(fold_)+'.csv',index=False)
    del temp_df, all_preds
# Out:
# FOLD: 0
# Predict | Day: 1
# ##########  1.08 min round |  1.08 min total |  3651.99 day sales |
# Predict | Day: 2
# ##########  0.82 min round |  1.91 min total |  3638.38 day sales |
# Predict | Day: 3
# ##########  0.87 min round |  2.78 min total |  3685.72 day sales |
# Predict | Day: 4
# ##########  0.88 min round |  3.66 min total |  3627.97 day sales |
# Predict | Day: 5
# ##########  0.91 min round |  4.56 min total |  4524.60 day sales |
# Predict | Day: 6
# ##########  0.89 min round |  5.46 min total |  5972.81 day sales |
# Predict | Day: 7
# ##########  0.87 min round |  6.33 min total |  5786.74 day sales |
# Predict | Day: 8
# ##########  0.93 min round |  7.25 min total |  4025.03 day sales |
# Predict | Day: 9
# ##########  0.90 min round |  8.16 min total |  3897.91 day sales |
# Predict | Day: 10
# ##########  0.85 min round |  9.01 min total |  3804.72 day sales |
# Predict | Day: 11
# ##########  0.91 min round |  9.92 min total |  3894.15 day sales |
# Predict | Day: 12
# ##########  0.93 min round |  10.86 min total |  4552.51 day sales |
# Predict | Day: 13
# ##########  0.91 min round |  11.76 min total |  5777.09 day sales |
# Predict | Day: 14
# ##########  0.88 min round |  12.65 min total |  4836.94 day sales |
# Predict | Day: 15
# ##########  0.96 min round |  13.61 min total |  4053.14 day sales |
# Predict | Day: 16
# ##########  0.86 min round |  14.47 min total |  3864.41 day sales |
# Predict | Day: 17
# ##########  0.97 min round |  15.44 min total |  3777.43 day sales |
# Predict | Day: 18
# ##########  0.94 min round |  16.38 min total |  3862.90 day sales |
# Predict | Day: 19
# ##########  0.87 min round |  17.25 min total |  4598.77 day sales |
# Predict | Day: 20
# ##########  0.89 min round |  18.13 min total |  6170.91 day sales |
# Predict | Day: 21
# ##########  1.03 min round |  19.16 min total |  6186.61 day sales |
# Predict | Day: 22
# ##########  0.85 min round |  20.01 min total |  3967.08 day sales |
# Predict | Day: 23
# ##########  0.92 min round |  20.93 min total |  3802.56 day sales |
# Predict | Day: 24
# ##########  0.91 min round |  21.84 min total |  3806.14 day sales |
# Predict | Day: 25
# ##########  0.86 min round |  22.70 min total |  3822.86 day sales |
# Predict | Day: 26
# ##########  0.87 min round |  23.57 min total |  4603.79 day sales |
# Predict | Day: 27
# ##########  1.15 min round |  24.73 min total |  6306.63 day sales |
# Predict | Day: 28
# ##########  1.33 min round |  26.06 min total |  6241.08 day sales |
# FOLD: 1
# Predict | Day: 1
# ##########  1.23 min round |  1.23 min total |  3717.07 day sales |
# Predict | Day: 2
# ##########  1.26 min round |  2.49 min total |  3640.27 day sales |
# Predict | Day: 3
# ##########  1.43 min round |  3.92 min total |  3654.34 day sales |
# Predict | Day: 4
# ##########  1.94 min round |  5.86 min total |  3701.98 day sales |
# Predict | Day: 5
# ##########  1.80 min round |  7.67 min total |  4523.93 day sales |
# Predict | Day: 6
# ##########  1.92 min round |  9.58 min total |  5862.16 day sales |
# Predict | Day: 7
# ##########  1.81 min round |  11.39 min total |  5352.14 day sales |
# Predict | Day: 8
# ##########  1.98 min round |  13.36 min total |  4009.03 day sales |
# Predict | Day: 9
# ##########  1.83 min round |  15.20 min total |  3863.94 day sales |
# Predict | Day: 10
# ##########  1.89 min round |  17.09 min total |  3636.92 day sales |
# Predict | Day: 11
# ##########  1.84 min round |  18.93 min total |  3750.79 day sales |
# Predict | Day: 12
# ##########  1.85 min round |  20.78 min total |  4361.11 day sales |
# Predict | Day: 13
# ##########  1.83 min round |  22.61 min total |  5883.61 day sales |
# Predict | Day: 14
# ##########  1.87 min round |  24.48 min total |  5146.68 day sales |
# Predict | Day: 15
# ##########  1.86 min round |  26.34 min total |  3993.43 day sales |
# Predict | Day: 16
# ##########  1.89 min round |  28.23 min total |  3742.55 day sales |
# Predict | Day: 17
# ##########  1.87 min round |  30.10 min total |  3662.76 day sales |
# Predict | Day: 18
# ##########  1.87 min round |  31.97 min total |  3710.44 day sales |
# Predict | Day: 19
# ##########  1.82 min round |  33.79 min total |  4481.47 day sales |
# Predict | Day: 20
# ##########  1.82 min round |  35.61 min total |  6044.32 day sales |
# Predict | Day: 21
# ##########  1.86 min round |  37.47 min total |  6164.37 day sales |
# Predict | Day: 22
# ##########  1.83 min round |  39.30 min total |  3873.13 day sales |
# Predict | Day: 23
# ##########  1.85 min round |  41.15 min total |  3682.86 day sales |
# Predict | Day: 24
# ##########  1.79 min round |  42.95 min total |  3647.66 day sales |
# Predict | Day: 25
# ##########  1.85 min round |  44.80 min total |  3706.07 day sales |
# Predict | Day: 26
# ##########  1.85 min round |  46.64 min total |  4499.05 day sales |
# Predict | Day: 27
# ##########  1.87 min round |  48.51 min total |  5992.89 day sales |
# Predict | Day: 28
# ##########  1.84 min round |  50.35 min total |  5998.41 day sales |
# FOLD: 2
# Predict | Day: 1
# ##########  1.84 min round |  1.84 min total |  3794.28 day sales |
# Predict | Day: 2
# ##########  1.84 min round |  3.69 min total |  3712.44 day sales |
# Predict | Day: 3
# ##########  1.96 min round |  5.64 min total |  3729.82 day sales |
# Predict | Day: 4
# ##########  2.03 min round |  7.67 min total |  3653.83 day sales |
# Predict | Day: 5
# ##########  2.04 min round |  9.71 min total |  4527.95 day sales |
# Predict | Day: 6
# ##########  1.96 min round |  11.67 min total |  5708.63 day sales |
# Predict | Day: 7
# ##########  2.14 min round |  13.81 min total |  5967.93 day sales |
# Predict | Day: 8
# ##########  1.83 min round |  15.64 min total |  4013.04 day sales |
# Predict | Day: 9
# ##########  2.02 min round |  17.66 min total |  3855.74 day sales |
# Predict | Day: 10
# ##########  1.94 min round |  19.60 min total |  3732.69 day sales |
# Predict | Day: 11
# ##########  1.94 min round |  21.54 min total |  3868.34 day sales |
# Predict | Day: 12
# ##########  1.91 min round |  23.45 min total |  4589.08 day sales |
# Predict | Day: 13
# ##########  1.94 min round |  25.39 min total |  5764.25 day sales |
# Predict | Day: 14
# ##########  1.92 min round |  27.31 min total |  4779.90 day sales |
# Predict | Day: 15
# ##########  1.96 min round |  29.27 min total |  3952.75 day sales |
# Predict | Day: 16
# ##########  1.91 min round |  31.18 min total |  3765.56 day sales |
# Predict | Day: 17
# ##########  1.94 min round |  33.12 min total |  3687.73 day sales |
# Predict | Day: 18
# ##########  1.94 min round |  35.06 min total |  3722.48 day sales |
# Predict | Day: 19
# ##########  2.31 min round |  37.38 min total |  4507.87 day sales |
# Predict | Day: 20
# ##########  2.49 min round |  39.87 min total |  6022.56 day sales |
# Predict | Day: 21
# ##########  2.63 min round |  42.50 min total |  6194.15 day sales |
# Predict | Day: 22
# ##########  2.64 min round |  45.14 min total |  3919.62 day sales |
# Predict | Day: 23
# ##########  2.32 min round |  47.46 min total |  3753.74 day sales |
# Predict | Day: 24
# ##########  2.35 min round |  49.80 min total |  3750.77 day sales |
# Predict | Day: 25
# ##########  2.34 min round |  52.14 min total |  3730.47 day sales |
# Predict | Day: 26
# ##########  2.34 min round |  54.48 min total |  4500.48 day sales |
# Predict | Day: 27
# ##########  2.34 min round |  56.82 min total |  6034.74 day sales |
# Predict | Day: 28
# ##########  2.35 min round |  59.17 min total |  6175.31 day sales |
