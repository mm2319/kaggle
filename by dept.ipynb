# %%
import pandas as pd

# %%
foods1_fold0=pd.read_csv('all_preds_FOODS_1_0.csv')
foods1_fold1=pd.read_csv('all_preds_FOODS_1_1.csv')
foods1_fold2=pd.read_csv('all_preds_FOODS_1_2.csv')

# %%
foods1_fold0.head()
# Out:
#                             id        F1        F2        F3        F4  \
# 0  FOODS_1_001_CA_1_validation  0.769215  0.741214  0.752030  0.776379
# 1  FOODS_1_002_CA_1_validation  0.390462  0.400081  0.394975  0.416529
# 2  FOODS_1_003_CA_1_validation  0.800136  0.690551  0.750118  0.746319
# 3  FOODS_1_004_CA_1_validation  0.011072  0.969784  1.160856  2.388907
# 4  FOODS_1_005_CA_1_validation  1.437252  1.463511  1.593881  1.453171
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  1.068959  0.905559  0.837016  1.034885  0.805049  ...  0.770985  0.902412
# 1  0.517433  0.467852  0.522405  0.498024  0.517989  ...  0.534463  0.694932
# 2  0.851853  0.776900  0.704481  0.773496  0.739220  ...  0.832168  0.921311
# 3  4.562267  4.690076  5.111929  3.198475  3.675546  ...  5.914523  6.689238
# 4  1.686512  1.808281  1.605767  1.295300  1.248014  ...  1.387900  1.553630
#
#         F21       F22       F23       F24       F25       F26       F27  \
# ...

# %%
foods1_fold0.shape
# Out:
# (2160, 29)

# %%
foods1=pd.DataFrame()
foods1['id']=foods1_fold0['id']
for item in foods1_fold0:
    if item!='id':
        foods1[item]=(foods1_fold0[item]*(1/3))+(foods1_fold1[item]*(1/3))+(foods1_fold2[item]*(1/3))

# %%
foods1.head()
# Out:
#                             id        F1        F2        F3        F4  \
# 0  FOODS_1_001_CA_1_validation  0.762385  0.697632  0.712167  0.736504
# 1  FOODS_1_002_CA_1_validation  0.391390  0.416570  0.392196  0.418434
# 2  FOODS_1_003_CA_1_validation  0.788070  0.692368  0.714204  0.694399
# 3  FOODS_1_004_CA_1_validation  0.020361  1.180185  1.771966  2.965322
# 4  FOODS_1_005_CA_1_validation  1.319422  1.355774  1.435223  1.357467
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  1.019728  0.846999  0.844867  0.942745  0.813077  ...  0.865455  1.055419
# 1  0.492377  0.451385  0.488399  0.469808  0.523741  ...  0.503851  0.616351
# 2  0.857918  0.776284  0.796859  0.807829  0.798927  ...  0.827304  0.977150
# 3  4.333468  4.587911  4.729523  3.921311  4.469232  ...  6.026499  6.740744
# 4  1.535218  1.479575  1.479672  1.219749  1.225715  ...  1.385319  1.515223
#
#         F21       F22       F23       F24       F25       F26       F27  \
# ...

# %%
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')

# %%
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(foods1['id']))]=list(foods1[item])
# Out:
# /Users/shuozhang/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sub[sub['id']=='FOODS_1_001_CA_1_validation']
# Out:
#                                id        F1        F2        F3        F4  \
# 1612  FOODS_1_001_CA_1_validation  0.762385  0.697632  0.712167  0.736504
#
#             F5        F6        F7        F8        F9  ...       F19  \
# 1612  1.019728  0.846999  0.844867  0.942745  0.813077  ...  0.865455
#
#            F20       F21       F22      F23       F24       F25       F26  \
# 1612  1.055419  1.010424  0.813099  0.73632  0.729843  0.719147  0.821386
#
#            F27       F28
# 1612  1.093553  0.973467
#
# [1 rows x 29 columns]

# %%
sub.to_csv('lgb_bydept_fe6_noweather_foods1.csv',index=False)

# %%
foods2_fold0=pd.read_csv('all_preds_FOODS_2_0.csv')
foods2_fold1=pd.read_csv('all_preds_FOODS_2_1.csv')
foods2_fold2=pd.read_csv('all_preds_FOODS_2_2.csv')

# %%
foods2=pd.DataFrame()
foods2['id']=foods2_fold0['id']
for item in foods2_fold0:
    if item!='id':
        foods2[item]=(foods2_fold0[item]*(1/3))+(foods2_fold1[item]*(1/3))+(foods2_fold2[item]*(1/3))

# %%
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(foods2['id']))]=list(foods2[item])
sub.to_csv('lgb_bydept_fe6_noweather_foods2.csv',index=False)

# %%
foods3_fold0=pd.read_csv('all_preds_FOODS_3_0.csv')
foods3_fold1=pd.read_csv('all_preds_FOODS_3_1.csv')
foods3_fold2=pd.read_csv('all_preds_FOODS_3_2.csv')
foods3=pd.DataFrame()
foods3['id']=foods3_fold0['id']
for item in foods3_fold0:
    if item!='id':
        foods3[item]=(foods3_fold0[item]*(1/3))+(foods3_fold1[item]*(1/3))+(foods3_fold2[item]*(1/3))
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(foods3['id']))]=list(foods3[item])
sub.to_csv('lgb_bydept_fe6_noweather_foods3.csv',index=False)

# %%
hobbies1_fold0=pd.read_csv('all_preds_HOBBIES_1_0.csv')
hobbies1_fold1=pd.read_csv('all_preds_HOBBIES_1_1.csv')
hobbies1_fold2=pd.read_csv('all_preds_HOBBIES_1_2.csv')
hobbies1=pd.DataFrame()
hobbies1['id']=hobbies1_fold0['id']
for item in hobbies1_fold0:
    if item!='id':
        hobbies1[item]=(hobbies1_fold0[item]*(1/3))+(hobbies1_fold1[item]*(1/3))+(hobbies1_fold2[item]*(1/3))
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(hobbies1['id']))]=list(hobbies1[item])
sub.to_csv('lgb_bydept_fe6_noweather_hobbies1.csv',index=False)

# %%
hobbies2_fold0=pd.read_csv('all_preds_HOBBIES_2_0.csv')
hobbies2_fold1=pd.read_csv('all_preds_HOBBIES_2_1.csv')
hobbies2_fold2=pd.read_csv('all_preds_HOBBIES_2_2.csv')
hobbies2=pd.DataFrame()
hobbies2['id']=hobbies2_fold0['id']
for item in hobbies2_fold0:
    if item!='id':
        hobbies2[item]=(hobbies2_fold0[item]*(1/3))+(hobbies2_fold1[item]*(1/3))+(hobbies2_fold2[item]*(1/3))
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(hobbies2['id']))]=list(hobbies2[item])
sub.to_csv('lgb_bydept_fe6_noweather_hobbies2.csv',index=False)

# %%
household1_fold0=pd.read_csv('all_preds_HOUSEHOLD_1_0.csv')
household1_fold1=pd.read_csv('all_preds_HOUSEHOLD_1_1.csv')
household1_fold2=pd.read_csv('all_preds_HOUSEHOLD_1_2.csv')
household1=pd.DataFrame()
household1['id']=household1_fold0['id']
for item in household1_fold0:
    if item!='id':
        household1[item]=(household1_fold0[item]*(1/3))+(household1_fold1[item]*(1/3))+(household1_fold2[item]*(1/3))
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(household1['id']))]=list(household1[item])
sub.to_csv('lgb_bydept_fe6_noweather_household1.csv',index=False)

# %%
household2_fold0=pd.read_csv('all_preds_HOUSEHOLD_2_0.csv')
household2_fold1=pd.read_csv('all_preds_HOUSEHOLD_2_1.csv')
household2_fold2=pd.read_csv('all_preds_HOUSEHOLD_2_2.csv')
household2=pd.DataFrame()
household2['id']=household2_fold0['id']
for item in household2_fold0:
    if item!='id':
        household[item]=(household1_fold0[item]*(1/3))+(household1_fold1[item]*(1/3))+(household1_fold2[item]*(1/3))
sub=pd.read_csv('lgb_bydept_fe6_noweather.csv')
for item in sub:
    if item!='id':
        sub[item].loc[(sub['id'].isin(household1['id']))]=list(household1[item])
sub.to_csv('lgb_bydept_fe6_noweather_household1.csv',index=False)
